# %%
import pandas as pd

# %%
pd.options.display.max_columns = 100

# %%
items = pd.read_csv('c:\work\dev\python\progs\scraper\items.csv', sep=',')

# %%
items['Method:'].value_counts().sum()
# Out:
# 6393

# %%
items.shape
# Out:
# (6393, 209)

# %%
items.iloc[:6384].tail()
# Out:
#                                         Event           Fighter_left  \
# 6379  UFC Fight Night: Holloway vs. Rodriguez       Cynthia Calvillo
# 6380  UFC Fight Night: Holloway vs. Rodriguez        Felicia Spencer
# 6381  UFC Fight Night: Holloway vs. Rodriguez          Marc Diakiese
# 6382         UFC Fight Night: Vieira vs. Tate  Shayilan Nuerdanbieke
# 6383         UFC Fight Night: Vieira vs. Tate            Davey Grant
#
#      Fighter_right Win_lose_left Win_lose_right               Method:  Round:  \
# 6379    Andrea Lee             L              W                KO/TKO       2
# 6380   Leah Letson             W              L                KO/TKO       3
# 6381  Rafael Alves             L              W            Submission       1
# 6382  Sean Soriano             W              L  Decision - Unanimous       3
# 6383  Adrian Yanez             L              W      Decision - Split       3
#
#      Time:   Time format:    Referee:  \
# 6379  5:00  3 Rnd (5-5-5)  Mark Smith
# ...
